# %%
import os
import openai
import csv
import string

countKeywords = 20

openai.api_key = "[API-KEY]"

countrylist = ""

count = 0
with open('../../Data/Country.csv', newline='', errors='backslashreplace') as csvfile:
    list = csv.reader(csvfile, delimiter=';', quotechar='"')

    with open('country_keywords_weather.csv', 'w', newline='', errors='backslashreplace') as csvfile:

        fieldnames = ['country', 'keywords']
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()

        for row in list:
            if(row[0] == "Country"): 
                continue
            promptStr = "How is the climate in "+row[0]+"? Give me the answer as a list of "+ str(countKeywords) +" keyword"

            completion = openai.Completion.create(
                model="text-davinci-003",
                prompt= promptStr,
                temperature=0.5,
                max_tokens=1024,
                top_p=1.0,
                frequency_penalty=0.0,
                presence_penalty=0.0
            )
        
            response = completion.choices[0].text
            first = True
            keywordList = ""
            print(response)
            for keyword in response.splitlines():
                if(keyword.isspace() or keyword == ""):
                    continue

                if(first):
                    first = False
                else:
                    keywordList = keywordList + ","
                
                keywordSplitted = keyword.split(" ", 1)
                
                keywordCorrected = keyword
                if(len(keywordSplitted) > 1):
                    keywordCorrected = keywordSplitted[1]

                keywordList = keywordList + keywordCorrected.strip()

            writer.writerow({'country': row[0].strip(), 'keywords': keywordList.strip()})

            count = count + 1
            print("Finished " + str(count) + "/226 (" + str(count/226) + "%)")
# Out:
# 1. Hot
# 2. Dry
# 3. Arid
# 4. Humid
# 5. Temperate
# 6. Mountainous
# 7. Desert
# 8. Extreme
# 9. Continental
# 10. Cold
# 11. Windy
# 12. Severe
# 13. Variable
# 14. Rainy
# 15. Unpredictable
# 16. Snowy
# 17. Monsoonal
# 18. Subtropical
# 19. Unstable
# 20. Harsh
# Finished 1/226 (0.004424778761061947%)
#
#
# 1. Mediterranean
# 2. Mild
# 3. Temperate
# 4. Hot Summers
# 5. Cold Winters
# 6. Rainy
# 7. Snowy
# 8. Humid
# 9. Sunny
# 10. Windy
# 11. Changeable
# 12. Oceanic
# 13. Continental
# 14. Mountainous
# 15. Coastal
# 16. Mediterranean Climate
# 17. Alpine Climate
# 18. Subtropical Climate
# 19. Mediterranean-Continental Climate
# 20. Mediterranean-Mountain Climate
# Finished 2/226 (0.008849557522123894%)
#
#
# 1. Hot
# 2. Arid
# 3. Dry
# 4. Mediterranean
# 5. Humid
# 6. Subtropical
# 7. Desert
# 8. Mild
# 9. Temperate
# 10. Continental
# 11. Summer
# 12. Winter
# 13. Spring
# 14. Fall
# 15. Rainy
# 16. Windy
# 17. Stormy
# 18. Sunny
# 19. Cloudy
# 20. Variable
# ...

# %%
import os
import openai
import csv
import string

countKeywords = 100

openai.api_key = "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"

countrylist = ""

count = 0
with open('../../Data/Country.csv', newline='', errors='backslashreplace') as csvfile:
    list = csv.reader(csvfile, delimiter=';', quotechar='"')

    with open('country_keywords_vegetation.csv', 'w', newline='', errors='backslashreplace') as csvfile:

        fieldnames = ['country', 'keywords']
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()

        for row in list:
            if(row[0] == "Country"): 
                continue
            promptStr = "What vegetation has " + row[0] + "? Give me the answer as a list of "+ str(countKeywords) +" keyword"

            completion = openai.Completion.create(
                model="text-davinci-003",
                prompt= promptStr,
                temperature=0.5,
                max_tokens=1024,
                top_p=1.0,
                frequency_penalty=0.0,
                presence_penalty=0.0
            )
        
            response = completion.choices[0].text
            first = True
            keywordList = ""
            print(response)
            for keyword in response.splitlines():
                if(keyword.isspace() or keyword == ""):
                    continue

                if(first):
                    first = False
                else:
                    keywordList = keywordList + ","
                
                keywordSplitted = keyword.split(" ", 1)
                
                keywordCorrected = keyword
                if(len(keywordSplitted) > 1):
                    keywordCorrected = keywordSplitted[1]

                keywordList = keywordList + keywordCorrected.strip()

            writer.writerow({'country': row[0].strip(), 'keywords': keywordList.strip()})

            count = count + 1
            print("Finished " + str(count) + "/226 (" + str(count/226) + "%)")
# Out:
# 1. Juniper
# 2. Pistachio
# 3. Mulberry
# 4. Pomegranate
# 5. Fig
# 6. Almond
# 7. Walnut
# 8. Poplar
# 9. Willow
# 10. Apple
# 11. Apricot
# 12. Plum
# 13. Mulberry
# 14. Date
# 15. Grape
# 16. Quince
# 17. Tamarisk
# 18. Oak
# 19. Maple
# 20. Ash
# 21. Cedar
# 22. Fir
# 23. Spruce
# 24. Birch
# 25. Juniper
# 26. Cypress
# 27. Eucalyptus
# 28. Acacia
# 29. Pistacia
# 30. Prunus
# 31. Tamarix
# 32. Salix
# 33. Salvia
# 34. Artemisia
# 35. Astragalus
# 36. Onobrychis
# 37. Caragana
# 38. Hedysarum
# 39. Astragalus
# 40. Haloxylon
# 41. Ephedra
# 42. Lycium
# 43. Tamarix
# 44. Nitraria
# 45. Haloxylon
# 46. Allium
# 47. Anchusa
# 48. Verbascum
# 49. Centaurea
# 50. Echinops
# 51. Thymus
# 52. Alyssum
# 53. Salvia
# 54. Euphorbia
# 55. Trigonella
# 56. Salsola
# 57. Sisymbrium
# 58. Ferula
# 59. Coriandrum
# 60. Capparis
# 61. Eryngium
# 62. Scorzonera
# 63. Scorzonera
# 64. Artemisia
# 65. Trigonella
# 66. Lamiaceae
# 67. Onobrychis
# 68. Astragalus
# 69. Vicia
# 70. Papaver
# ...

# %%
import os
import openai
import csv
import string

countKeywords = 20

openai.api_key = "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"

countrylist = ""

count = 0
with open('../../Data/Country.csv', newline='', errors='backslashreplace') as csvfile:
    list = csv.reader(csvfile, delimiter=';', quotechar='"')

    with open('country_keywords_culture.csv', 'w', newline='', errors='backslashreplace') as csvfile:

        fieldnames = ['country', 'keywords']
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()

        for row in list:
            if(row[0] == "Country"): 
                continue
            promptStr = "What culture has " + row[0] + "? Give me the answer as a list of "+ str(countKeywords) +" keyword"

            completion = openai.Completion.create(
                model="text-davinci-003",
                prompt= promptStr,
                temperature=0.5,
                max_tokens=1024,
                top_p=1.0,
                frequency_penalty=0.0,
                presence_penalty=0.0
            )
        
            response = completion.choices[0].text
            first = True
            keywordList = ""
            print(response)
            for keyword in response.splitlines():
                if(keyword.isspace() or keyword == ""):
                    continue

                if(first):
                    first = False
                else:
                    keywordList = keywordList + ","
                
                keywordSplitted = keyword.split(" ", 1)
                
                keywordCorrected = keyword
                if(len(keywordSplitted) > 1):
                    keywordCorrected = keywordSplitted[1]

                keywordList = keywordList + keywordCorrected.strip()

            writer.writerow({'country': row[0].strip(), 'keywords': keywordList.strip()})

            count = count + 1
            print("Finished " + str(count) + "/226 (" + str(count/226) + "%)")
# Out:
# 1. Islam
# 2. Pashtun
# 3. Persian
# 4. Balochi
# 5. Turkmen
# 6. Uzbek
# 7. Tajik
# 8. Nuristani
# 9. Arab
# 10. Aimaq
# 11. Hazara
# 12. Kyrgyz
# 13. Pashayi
# 14. Pamiri
# 15. Nuristani
# 16. Turkic
# 17. Qizilbash
# 18. Brahui
# 19. Qizilbash-Aimaq
# 20. Art and Music
# Finished 1/226 (0.004424778761061947%)
#
#
# 1. Albanian Language
# 2. Albanian Music
# 3. Albanian Cuisine
# 4. Albanian Folklore
# 5. Albanian Art
# 6. Albanian Literature
# 7. Albanian Religion
# 8. Albanian Architecture
# 9. Albanian Clothing
# 10. Albanian Dance
# 11. Albanian Customs
# 12. Albanian Traditions
# 13. Albanian Family Values
# 14. Albanian Hospitality
# 15. Albanian Hospitality Customs
# 16. Albanian Greetings
# 17. Albanian Greetings Customs
# 18. Albanian Greetings Traditions
# 19. Albanian Festivals
# 20. Albanian Celebrations
# Finished 2/226 (0.008849557522123894%)
#
#
# 1. Berber
# 2. Arab
# 3. Islamic
# 4. French
# 5. Mediterranean
# 6. Music
# 7. Art
# 8. Cuisine
# 9. Literature
# ...

# %%
import os
import openai
import csv
import string

countKeywords = 100

openai.api_key = "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"

countrylist = ""

count = 0
with open('../../Data/Country.csv', newline='', errors='backslashreplace') as csvfile:
    list = csv.reader(csvfile, delimiter=';', quotechar='"')

    with open('country_keywords_food.csv', 'w', newline='', errors='backslashreplace') as csvfile:

        fieldnames = ['country', 'keywords']
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()

        for row in list:
            if(row[0] == "Country"): 
                continue
            promptStr = "What food has " + row[0] + "? Give me the answer as a list of "+ str(countKeywords) +" keyword"

            completion = openai.Completion.create(
                model="text-davinci-003",
                prompt= promptStr,
                temperature=0.5,
                max_tokens=2048,
                top_p=1.0,
                frequency_penalty=0.0,
                presence_penalty=0.0
            )
        
            response = completion.choices[0].text
            first = True
            keywordList = ""
            print(response)
            for keyword in response.splitlines():
                if(keyword.isspace() or keyword == ""):
                    continue

                if(first):
                    first = False
                else:
                    keywordList = keywordList + ","
                
                keywordSplitted = keyword.split(" ", 1)
                
                keywordCorrected = keyword
                if(len(keywordSplitted) > 1):
                    keywordCorrected = keywordSplitted[1]

                keywordList = keywordList + keywordCorrected.strip()

            writer.writerow({'country': row[0].strip(), 'keywords': keywordList.strip()})

            count = count + 1
            print("Finished " + str(count) + "/226 (" + str(count/226) + "%)")
# Out:
# 1. Kabuli Palaw
# 2. Mantu
# 3. Bolani
# 4. Qorma
# 5. Shorwa
# 6. Aushak
# 7. Ashak
# 8. Kebab
# 9. Quabili Pallow
# 10. Shami Kebab
# 11. Aush
# 12. Kofta
# 13. Biryani
# 14. Kaddo
# 15. Chalau
# 16. Sheer Birinj
# 17. Bolani Lawang
# 18. Naan
# 19. Bolani Kadu
# 20. Mantu Palaw
# 21. Bolani Banjan
# 22. Bolani Kadu
# 23. Kichiri
# 24. Kebab-e-Mazari
# 25. Kebab-e-Qorma
# 26. Kebab-e-Barg
# 27. Kebab-e-Kofta
# 28. Kebab-e-Shami
# 29. Kebab-e-Tikka
# 30. Kebab-e-Kabuli
# 31. Kebab-e-Lamb
# 32. Kebab-e-Khameer
# 33. Kebab-e-Chalow
# 34. Kebab-e-Kabab
# 35. Kebab-e-Korma
# 36. Kebab-e-Kofta-e-Palaw
# 37. Kebab-e-Lamb-e-Palaw
# 38. Kebab-e-Kofta-e-Kabab
# 39. Kebab-e-Tikka-e-Kabab
# 40. Kebab-e-Kabab-e-Kabab
# 41. Kebab-e-Kofta-e-Kabab-e-Kabab
# 42. Kebab-e-Kofta-e-Barg
# 43. Kebab-e-Kofta-e-Tikka
# 44. Kebab-e-Kofta-e-Korma
# 45. Kebab-e-Kofta-e-Kofta
# 46. Kebab-e-Kofta-e-Lamb
# 47. Kebab-e-Kofta-e-Kofta-e-Palaw
# 48. Kebab-e-Kofta-e-Kabab-e-Kabab
# 49. Kebab-e-Kofta-e-Kabab-e-Barg
# ...
