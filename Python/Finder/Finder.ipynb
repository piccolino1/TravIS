# %%
'''Import basic modules.'''
import pandas as pd
import numpy as np

df = pd.read_csv('../ChatGPT/country_keywords.csv', encoding='latin-1', sep=';',)
df.head()
# Out:
#           country                                           keywords
# 0     Afghanistan  Afghanistan ,Kabul ,Bamiyan ,Kandahar ,Herat ,...  \
# 1         Albania  Albania ,Tirana ,Albanian Riviera ,Shkodra ,Sa...
# 2         Algeria  Algeria ,North Africa ,Sahara Desert ,Algiers ...
# 3  American Samoa  American Samoa,Samoa,Pago Pago,South Pacific,T...
# 4         Andorra  Andorra,Andorran,Principality of Andorra,Andor...
#
#                                     keywords climate
# 0  Hot,Dry,Arid,Humid,Temperate,Mountainous,Deser...  \
# 1  Mediterranean,Mild,Temperate,Hot Summers,Cold ...
# 2  Hot,Arid,Dry,Mediterranean,Humid,Subtropical,D...
# 3  Tropical,Humid,Hot,Wet,Rainy,Oceanic,Maritime,...
# 4  Mild,Temperate,Mediterranean,Alpine,Snowy,Rain...
#
#                                        keywords food
# 0  Kabuli Palaw,Mantu,Bolani,Qorma,Shorwa,Aushak,...  \
# 1  Burek,Kofte,Tavë Kosi,Byrek,Fërgesë,Qofte me M...
# 2  Couscous,Merguez,Mechoui,Chorba,Harira,Tanjia,...
# 3  Taro,Fish,Coconut,Breadfruit,Bananas,Papayas,M...
# 4  Catalan cuisine,Escudella,Cargols,Trinxat,Escu...
#
#                                  keywords vegetation
# 0  Juniper,Pistachio,Mulberry,Pomegranate,Fig,Alm...  \
# 1  Oak,Beech,Pine,Juniper,Birch,Chestnut,Hazel,Ma...
# 2  Olive trees,Date palms,Juniper,Eucalyptus,Cypr...
# 3  Coconut Palm,Pandanus,Hibiscus,Bougainvillea,P...
# 4  Alpine Grassland,Juniper,Pinus sylvestris,Fagu...
#
#                                     keywords culture
# 0  Islam,Pashtun,Persian,Balochi,Turkmen,Uzbek,Ta...
# 1  Albanian Language,Albanian Music,Albanian Cuis...
# 2  Berber,Arab,Islamic,French,Mediterranean,Music...
# 3  Fa'a Samoa,Samoan language,Tapu,Fa'amatai,Aiga...
# 4  Catalan,Romance Language,Skiing,Hiking,Snowboa...

# %%
new_df = df
new_df.head()
new_df.dropna(inplace=True)

blanks = []  # start with an empty list

col=['country','keywords','keywords climate','keywords food','keywords vegetation','keywords culture']
for i,col in new_df.iterrows():  # iterate over the DataFrame
    if type(col)==str:            # avoid NaN values
        if col.isspace():         # test 'review' for whitespace
            blanks.append(i)     # add matching index numbers to the list

new_df.drop(blanks, inplace=True)

new_df['keywords'] = new_df['keywords'].map(lambda x: x.lower().split(','))
new_df['keywords climate'] = new_df['keywords climate'].map(lambda x: x.lower().split(','))
new_df['keywords food'] = new_df['keywords food'].map(lambda x: x.lower().split(','))
new_df['keywords vegetation'] = new_df['keywords vegetation'].map(lambda x: x.lower().split(','))
new_df['keywords culture'] = new_df['keywords culture'].map(lambda x: x.lower().split(','))

new_df.set_index('country', inplace = True)
new_df.head()

new_df
# Out:
#                                                          keywords
# country
# Afghanistan     [afghanistan , kabul , bamiyan , kandahar , he...  \
# Albania         [albania , tirana , albanian riviera , shkodra...
# Algeria         [algeria , north africa , sahara desert , algi...
# American Samoa  [american samoa, samoa, pago pago, south pacif...
# Andorra         [andorra, andorran, principality of andorra, a...
# ...                                                           ...
# West Bank       [west bank, palestine, occupied territories, j...
# Western Sahara  [western sahara, sahrawi, desert, sahara, tind...
# Yemen           [yemen , sana'a , aden , ta'izz , al hudaydah ...
# Zambia          [zambia , lusaka , victoria falls , safari, ad...
# Zimbabwe        [zimbabwe, harare, victoria falls, safari, adv...
#
#                                                  keywords climate
# country
# Afghanistan     [hot, dry, arid, humid, temperate, mountainous...  \
# Albania         [mediterranean, mild, temperate, hot summers, ...
# Algeria         [hot, arid, dry, mediterranean, humid, subtrop...
# American Samoa  [tropical, humid, hot, wet, rainy, oceanic, ma...
# Andorra         [mild, temperate, mediterranean, alpine, snowy...
# ...                                                           ...
# West Bank       [hot, dry, mediterranean, semi-arid, humid, su...
# Western Sahara  [arid, desert, hot, dry, humid, extremely hot,...
# Yemen           [hot, dry, arid, desert, humid, subtropical, m...
# Zambia          [tropical, humid, hot, rainy, dry, semiarid, s...
# Zimbabwe        [tropical, humid, hot, subtropical, monsoonal,...
#
#                                                     keywords food
# country
# Afghanistan     [kabuli palaw, mantu, bolani, qorma, shorwa, a...  \
# Albania         [burek, kofte, tavë kosi, byrek, fërgesë, qoft...
# Algeria         [couscous, merguez, mechoui, chorba, harira, t...
# American Samoa  [taro, fish, coconut, breadfruit, bananas, pap...
# Andorra         [catalan cuisine, escudella, cargols, trinxat,...
# ...                                                           ...
# West Bank       [falafel, hummus, shawarma, tabbouleh, kebab, ...
# Western Sahara  [couscous, tagine, bread, fish, lamb, dates, o...
# Yemen           [yemeni flatbread, saltah, ful medames, kabsa,...
# Zambia          [nshima, kapenta, matemba, chikanda, millet, c...
# Zimbabwe        [sadza, chakalaka, pap, nhopi, matemba, grille...
#
#                                               keywords vegetation
# country
# Afghanistan     [juniper, pistachio, mulberry, pomegranate, fi...  \
# Albania         [oak, beech, pine, juniper, birch, chestnut, h...
# Algeria         [olive trees, date palms, juniper, eucalyptus,...
# American Samoa  [coconut palm, pandanus, hibiscus, bougainvill...
# Andorra         [alpine grassland, juniper, pinus sylvestris, ...
# ...                                                           ...
# West Bank       [olive trees, grapevines, cypress trees, alepp...
# Western Sahara  [argan trees, acacia trees, tamarisk trees, pr...
# Yemen           [acacia, aloe, anise, banana, barley, basil, b...
# Zambia          [mopane, baobab, acacia, combretum, brachysteg...
# Zimbabwe        [acacia, albizia, baobab, brachystegia, combre...
#
#                                                  keywords culture
# country
# Afghanistan     [islam, pashtun, persian, balochi, turkmen, uz...
# Albania         [albanian language, albanian music, albanian c...
# Algeria         [berber, arab, islamic, french, mediterranean,...
# American Samoa  [fa'a samoa, samoan language, tapu, fa'amatai,...
# Andorra         [catalan, romance language, skiing, hiking, sn...
# ...                                                           ...
# West Bank       [palestinian, islam, arabic, middle east, arab...
# Western Sahara  [berber, islamic, sahrawi, arabic, tuareg, has...
# Yemen           [tribalism, islam, arabic, coffee, cuisine, mu...
# Zambia          [bemba, kaonde, lunda, luvale, nyanja, tonga, ...
# Zimbabwe        [shona, ndebele, music, dance, cuisine, clothi...
#
# [226 rows x 5 columns]

# %%
new_df['bag_of_words'] = ''
columns = new_df.columns
for index, row in df.iterrows():
    words = ''
    for col in columns:
            words = words + ' '.join(row[col])+ ' '
    new_df['bag_of_words'][index] = words
    
new_df.drop(columns = [col for col in df.columns if col!= 'bag_of_words'], inplace = True)

new_df
# Out:
#                                                      bag_of_words
# country
# Afghanistan     afghanistan  kabul  bamiyan  kandahar  herat  ...
# Albania         albania  tirana  albanian riviera  shkodra  sa...
# Algeria         algeria  north africa  sahara desert  algiers ...
# American Samoa  american samoa samoa pago pago south pacific t...
# Andorra         andorra andorran principality of andorra andor...
# ...                                                           ...
# West Bank       west bank palestine occupied territories jerus...
# Western Sahara  western sahara sahrawi desert sahara tindouf l...
# Yemen           yemen  sana'a  aden  ta'izz  al hudaydah  al m...
# Zambia          zambia  lusaka  victoria falls  safari adventu...
# Zimbabwe        zimbabwe harare victoria falls safari adventur...
#
# [226 rows x 1 columns]

# %%
from sklearn.feature_extraction import text
vectorizer = text.TfidfVectorizer()

def cosine_sim(test1, test2):
    tfidf = vectorizer.fit_transform([test1, test2])
    result = ((tfidf * tfidf.T).A)[0,1]
    return result
    
def cosine_sim_df(df_data, keyword):
    col1 = 'bag_of_words'
    col2 = 'keyword'
    df_data[col1] = df_data[col1].str.replace(r'\d', '')
    df_data[col2] = keyword.lower()
    
    df_data['cos_sim'] = 0
    df_data['cos_sim'] = df_data.apply(
        lambda x: cosine_sim(x[col1], x[col2]), axis=1)
    
    df_data = df_data.sort_values(by='cos_sim', ascending=False)
    return df_data

new_df = cosine_sim_df(new_df, 'oktoberfest')
new_df
# Out:
#                                                      bag_of_words
# country
# Germany         germany  berlin  bavaria  munich  rhine  frank...  \
# United States   usa united states america national parks vacat...
# Peru            peru  machu picchu  inca  cusco  amazon  lima ...
# Czech Republic  prague czech republic charles bridge czech foo...
# Armenia         armenia  yerevan  tourist attractions  histori...
# ...                                                           ...
# Senegal         senegal  dakar  west africa  gorée island  cas...
# American Samoa  american samoa samoa pago pago south pacific t...
# Seychelles      seychelles beaches islands vacations hotels re...
# Sierra Leone    sierra leone  freetown  west africa  beaches  ...
# Latvia          latvia  riga  baltic sea  latvian  daugava riv...
#
#                     keyword   cos_sim
# country
# Germany         oktoberfest  0.009553
# United States   oktoberfest  0.000000
# Peru            oktoberfest  0.000000
# Czech Republic  oktoberfest  0.000000
# Armenia         oktoberfest  0.000000
# ...                     ...       ...
# Senegal         oktoberfest  0.000000
# American Samoa  oktoberfest  0.000000
# Seychelles      oktoberfest  0.000000
# Sierra Leone    oktoberfest  0.000000
# Latvia          oktoberfest  0.000000
#
# [226 rows x 3 columns]
